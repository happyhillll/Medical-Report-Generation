# %% [markdown]
# <a href="https://colab.research.google.com/github/happyhillll/Medical-Report-Generation/blob/main/Medical_Report_Generation_(preprocessing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os
import sklearn
import tqdm
from tqdm import tqdm
import nltk
import warnings
warnings.filterwarnings("ignore") 
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/MyDrive/하울스 1팀 : medical report generation/Self Case Study 2")

# %% [markdown]
# 각 파일에 몇개의 image와 report가 있는지 확인한다.

# %%
 print("there are {} number of reports in the data ".format(len(os.listdir("ecgen-radiology"))))
print("there are {} number of x-rays in the data ".format(len(os.listdir("NLMCXR_png"))))
# Out:
# there are 3955 number of reports in the data
# there are 7471 number of x-rays in the data

# %% [markdown]
# - image 가 report보다 개수가 많은 이유는 report 하나당 1개 이상의 x-ray 사진이 포함되어 있을 수 있기 때문이다. (정면, 측면)

# %% [markdown]
# ##Extracting the medical reports from the xml file
# - medical report는 xml 파일의 형식으로 저장되어 있다.
# - 각각의 xml 파일에는 실질적인 report 이외에도 많은 데이터들이 들어있다.
# - 우리는 x-ray 사진들에 해당이 되는 알맞은 report가 학습이 되도록 x-ray를 고르는 작업이 필요하다.
# - image의  id는 xml 파일에 포함되어있다.

# %%
'''from google.colab import files
files=files.upload()'''
# Out:
#      <input type="file" id="files-0b01a420-3985-4b00-b7fc-da585ae74a76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b01a420-3985-4b00-b7fc-da585ae74a76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
from IPython.display import Image
Image("report sample.PNG", width=1000, height=800)

# %% [markdown]
# extracting findings,impression,and indication from these xml files as reports.
# Also, extracting the image ids to get the x-ray corresponding to that report

# %%
#https://www.geeksforgeeks.org/xml-parsing-python/

import xml.etree.ElementTree as et #xml 파일을 읽기.
id=[] #빈 리스트 생성
finding=[]
count=[]
indication=[]
impression=[]

for report in tqdm(os.listdir("ecgen-radiology")):  # tqdm: 진행표시바 / os.listdir() : 지정된 디렉토리 내의 모든 파일과 list를 리턴
  #create element tree object
  tree=et.parse("ecgen-radiology/"+report)  #tree라는 파일 parsing하여 쓰기
  #get the root element
  root=tree.getroot()  #root는 xml 문서의 최상단 루트 태그를 가리키게 된다.
  '''
  <et의 xml 태그 구성 >
  tag : 해당 태그 이름
  text : 해당 태그의 값
  attrib : 해당 노드의 attribute 맵 (key,value)
  '''
  #inside the root element
  for child in root:  #root 안에서 찾기
      if child.tag == "MedlineCitation":  
          for each in child:  
              if each.tag == "Article":  
                  for i in each:
                      if i.tag == "Abstract":  #셋다 포함이 되어있는 tag의 텍스트: comparison,indication,findings,impression -> label
                          for j in i:          

                            if j.get('Label')=='INDICATION':
                              indic=j.text    #Positive TB test
                              
                            if j.get("Label") == "FINDINGS":
                              find = j.text   #The cardiac silhouette and mediastinum size are within normal
                                
                            if j.get('Label')=='IMPRESSION':
                              impr=j.text    #Normal chest x-XXXX.
                              
                                       
  image_count=0 #this is to find the number of x-rays in each report 
  for img_id in root.findall("parentImage"): #"parentImage"가 담겨있는 모든 열에서 하나씩
    id.append(img_id.get("id")+".png")   #비어있는 리스트 id에 parentImage열 id(/parentImage/@id)를 불러와서 "아이디.png"로 바꿔서 append
    #이때 이미지가 두 개이면, id도 두 개
    finding.append(find)       #finding 변수에 find append
    impression.append(impr)
    indication.append(indic)
    image_count+=1     #for문 한 번이 끝나면 image를 하나 count 해줌
  count.append(image_count)  #빈 count 리스트에 append
# Out:
# 100%|██████████| 3955/3955 [01:00<00:00, 65.50it/s]

# %%
from IPython.display import Image
Image("reprt 2.PNG", width=1000, height=800)

# %% [markdown]
# ## id와 image, report 가 들어간 dataframe 생성하기

# %%
df=pd.DataFrame()   #dataframe 생성
patient_id=[i[:-9] for i in id]  #id 에서 i 9자리를 하나씩 꺼내서 patient_id 에 저장 ????? 근데 출력되는건 9자리가 아님 
df["patient_id"]=patient_id    #df의 "patient_id" 열 선택하여 patient_id에 대입하기
df["image_id"]=["NLMCXR_png/"+ i for i in id] #id에서 하나씩 뽑은 i에 "NLMCXR_png/"를 append하여 image_id 열에 저장
df["finding"]=finding
df["impression"]=impression
df["indication"]=indication

print(df.shape) #df.shape : dataframe의 row 와 column 수 출력
df
# Out:
# (7470, 5)
#                 patient_id  ...                                         indication
# 0          CXR3696_IM-1846  ...         preop for XXXX surgery XXXX surgery on jaw
# 1          CXR3696_IM-1846  ...         preop for XXXX surgery XXXX surgery on jaw
# 2     CXR3681_IM-1833-0001  ...    Right-sided chest pain and shortness of breath.
# 3     CXR3681_IM-1833-0001  ...    Right-sided chest pain and shortness of breath.
# 4     CXR3676_IM-1829-0001  ...                      XXXX-year-old male with XXXX.
# ...                    ...  ...                                                ...
# 7465       CXR1851_IM-0553  ...          XXXX-year-old male with XXXX and dyspnea.
# 7466       CXR1877_IM-0568  ...                                               XXXX
# 7467       CXR1877_IM-0568  ...                                               XXXX
# 7468        CXR186_IM-0558  ...  XXXX year old woman, question swallowed foreig...
# ...

# %% [markdown]
# ## Report의 길이 알아내기

# %%
#check the lengths of reports
length=[]
for report in df["finding"]:  #finding 열에서 하나씩 꺼내서
  try:  #오류 예외 처리 기법: try 블록 수행 중 오류가 발생하면 except 블록이 수행된다.
    length.append(len(report.split()))  #빈 리스트에 report를 띄어쓰기 기준으로 개수를 세서 append
  except:
    pass 
length=np.array(length)  #length 배열을 생성
print("the mean lengths of reports is ",np.mean(length)) #평균
print("the 80th percentile lengths of reports is ",np.percentile(length,80)) 
print("the 90th percentile lengths of reports is ",np.percentile(length,90))
print("the 99th percentile lengths of reports is ",np.percentile(length,99))
print("the maximum value of lengths of reports is ",np.max(length))
# Out:
# the mean lengths of reports is  31.32164375096555
# the 80th percentile lengths of reports is  41.0
# the 90th percentile lengths of reports is  50.0
# the 99th percentile lengths of reports is  79.0
# the maximum value of lengths of reports is  169

# %% [markdown]
# 99퍼센트의 리포트는 80이하의 길이를 가지고 있다.

# %% [markdown]
# ## 샘플 x-ray와 finding 출력 + 이미지 다루기

# %%
#print some sample x-rays and findings
a=np.random.choice(range(7470),5) #np.random.choice : 임의표본 추출 -> 5개
for each in a:  #a에서 임의 추출된 5개 숫자 하나씩 불러와서, 
  img=cv2.imread(df.iloc[each]["image_id"])  #cv2.imread(filename): 이미지 파일 읽기 / df.iloc: 데이터프레임의 행이나 칼럼에 ""인덱스 값""으로 접근
  plt.imshow(img)     # df.iloc[임의의 인덱스]["image_id"열] #imshow(): 이미지 보기
  plt.show() 
  print("FINDINGS:",df.iloc[each]["finding"])
  print("IMPRESSION:",df.iloc[each]["impression"])
  print("INDICATION:",df.iloc[each]["indication"])
  print("*"*100)
# Out:
# FINDINGS: The cardiomediastinal silhouette and pulmonary vasculature are within normal limits in size. Lungs are mildly hypoinflated with minimal streaky atelectasis or scar in the lung bases. Lungs are otherwise grossly clear of focal airspace disease. There is a stable calcified granuloma in the posterior left midlung. There is no pneumothorax or pleural effusion. There are no acute bony findings.
# IMPRESSION: Mildly low lung volumes with XXXX atelectasis or scarring in the lung bases.
# INDICATION: XXXX to inside of cheek, shortness of breath.
# ****************************************************************************************************
# FINDINGS: Heart size and pulmonary vascularity appear within normal limits. The lungs are free of focal airspace disease. No pleural effusion or pneumothorax is seen. Low left paraspinal/retrocrural adenopathy is present. This appears unchanged.
# IMPRESSION: 1. Left paraspinal/retrocrural adenopathy.
# INDICATION: Testicular carcinoma.
# ...

# %% [markdown]
# 측면과 전면 x-ray가 함께 있음을 알 수 있으며, 데이터를 보았을때 finding을 통해 진단을 내린다는 것을 알 수 있다. 따라서 findings에 null이 없음을 확실히 해야한다.

# %% [markdown]
# ##Findings가 none인 report 개수 구하기

# %%
#finding the number of reports were findings is none
none=sum(df["finding"].isnull().values.ravel()) #df.isnull().values.ravel() : finding에서 NaN 값의 개수 찾기
print("there are {} number of records where finding is none".format(none))
# Out:
# there are 997 number of records where finding is none

# %% [markdown]
# 만약 finding이 빈칸이라면, finding 대신에 해당 image의 impression을 사용하도록 한다.

# %%
for i in range(df.shape[0]): #row 의 개수 / df.shape[1]: col count
  if finding[i] is None:   
    
    finding[i]=impression[i]  #비어있는 finding은 impression으로 채워준다.
    

df["finding"]=finding

# %%
none=sum(df["finding"].isnull().values.ravel())
print("there are {} number of records where finding is none".format(none))
# Out:
# there are 40 number of records where finding is none

# %% [markdown]
# finding과 impression이 모두 없는 열은 모두 drop 한다.

# %%
df=df.dropna()
none=sum(df["finding"].isnull().values.ravel())
print("there are {} number of records where finding is none".format(none))
df=df.drop(["impression","indication"],axis=1)
# Out:
# there are 0 number of records where finding is none

# %% [markdown]
# finding을 제외하고 모든 열은 drop 한다.

# %%
df
# Out:
#                 patient_id  ...                                            finding
# 0          CXR3696_IM-1846  ...  Heart size is normal and lungs are clear. Stab...
# 1          CXR3696_IM-1846  ...  Heart size is normal and lungs are clear. Stab...
# 2     CXR3681_IM-1833-0001  ...  There are lower lung volumes. There is central...
# 3     CXR3681_IM-1833-0001  ...  There are lower lung volumes. There is central...
# 4     CXR3676_IM-1829-0001  ...  The cardiomediastinal silhouette appears irreg...
# ...                    ...  ...                                                ...
# 7465       CXR1851_IM-0553  ...  Heart size is normal. No focal airspace consol...
# 7466       CXR1877_IM-0568  ...  Heart size normal. Lungs are clear. XXXX are n...
# 7467       CXR1877_IM-0568  ...  Heart size normal. Lungs are clear. XXXX are n...
# 7468        CXR186_IM-0558  ...  Cardiac size, mediastinal contour, and pulmona...
# ...

# %% [markdown]
# ####데이터를 살펴보면 한 환자 당 x-ray가 한개 이상인 것을 알 수 있다. 따라서 환자 한 명당 x-ray image의 개수를 확인하도록 한다.

# %%
d=dict()
for patient in df["patient_id"]:  #patient_id 열에서 하나씩 꺼내서
  if patient in d:     #만약 patient가 d에 이미 있으면 "patient"의 value에 1을 더하기. ex) patient:2
    d[patient]+=1
  else:
    d[patient]=1    #d에 없으면 patient:1

count=list(d.values())  #dic에서 모든 value를 보고싶으면 list로 묶어야함. > 묶어서 count변수에 저장
sns.countplot(count)  #countplot 명령: 각 카테고리 값별로 데이터가 얼마나 있는지 표시할 수 있다.
plt.title("number of image per patient ")  #plot title을 지정한다.
# Out:
# Text(0.5, 1.0, 'number of image per patient ')

# %% [markdown]
# 대부분의 report는 2개의 이미지를 가지고 있음을 알 수 있다. 반면, 3,4개의 이미지를 가지고 있는 환자도 존재한다.

# %% [markdown]
# ##3개 이상의 image를 가지고 있는 환자 분석

# %%
#https://www.geeksforgeeks.org/xml-parsing-python/

import xml.etree.ElementTree as et
img=[]

for report in tqdm(os.listdir("ecgen-radiology")):
  #create element tree object
  tree=et.parse("ecgen-radiology/"+report)
  
  root=tree.getroot()
  
  
  if len(root.findall("parentImage"))>3:  
    for img_id in root.findall("parentImage"):
    
      img.append(img_id.get("id")+".png")
  
    break
# Out:
#   7%|▋         | 258/3955 [00:02<00:34, 106.30it/s]

# %%
for i in img:
  image=cv2.imread("NLMCXR_png/"+i)
  plt.imshow(image)
  plt.show()

# %% [markdown]
# 대부분의 환자가 2개의 이미지를 가지고 있기 때문에 2개 이상의 이미지를 가지고 있는 환자는 임의로 두 개의 이미지를 고른다. 1개의 이미지를 가지고 있는 경우는 단순히 복제한다.

# %% [markdown]
# ####데이터프레임의 iloc,loc
# - df.iloc[0] : 인덱스 번호로 행 출력
# - df.iloc[[0]] : df 형태로 인덱스 번호 행 출력
# - df.iloc[0][0] : 인덱스 번호로 행,열번호로 출력 (1행1열)
# - df.iloc[0]["patient_id"]: 인덱스번호로 행,칼럼명으로 출력
# -----------------
# - df.loc[["1"]] : 지정한 인덱스로 행 접근
# - df.loc[["1"]]["patient_id"] : 칼럼명으로 열에 접근

# %%
print(d)
# Out:
# {'CXR3696_IM-1846': 2, 'CXR3681_IM-1833-0001': 2, 'CXR3676_IM-1829-0001': 2, 'CXR3671_IM-1827': 3, 'CXR3677_IM-1830': 2, 'CXR370_IM-1848': 2, 'CXR3661_IM-1821': 2, 'CXR3695_IM-1845': 2, 'CXR3687_IM-1838': 2, 'CXR3670_IM-1826': 2, 'CXR3688_IM-1839-0001': 2, 'CXR3680_IM-1832': 2, 'CXR3675_IM-1829-0001': 2, 'CXR3719_IM-1857': 2, 'CXR3708_IM-1852': 2, 'CXR376_IM-1883': 2, 'CXR3726_IM-1862': 2, 'CXR3723_IM-1860': 2, 'CXR375_IM-1874': 2, 'CXR3751_IM-1875': 2, 'CXR3736_IM-1866': 1, 'CXR3766_IM-1885': 2, 'CXR3713_IM-1855': 2, 'CXR3715_IM-1856': 2, 'CXR3756_IM-1880': 2, 'CXR3730_IM-1864': 2, 'CXR3704_IM-1851': 2, 'CXR3732_IM-1866': 2, 'CXR3752_IM-1876': 2, 'CXR3712_IM-1854': 2, 'CXR3744_IM-1871-0001': 2, 'CXR3761_IM-1883': 2, 'CXR3743_IM-1870': 1, 'CXR3706_IM-1851': 2, 'CXR3707_IM-1851': 2, 'CXR3757_IM-1881-': 1, 'CXR3757_IM-1881': 1, 'CXR3727_IM-1863': 2, 'CXR3721_IM-1859': 2, 'CXR3738_IM-1867': 2, 'CXR3750_IM-1874': 1, 'CXR3718_IM-1856': 1, 'CXR3737_IM-1867': 2, 'CXR3716_IM-1856': 3, 'CXR37
# ...

# %%
d=dict() #where key is the patient id and value is the images. ex)id:images
d1=dict() # where key is the patient id and value is the report or findings. ex)id:report/findings
for row in range(df.shape[0]): #위에서 만든 df 행의 개수만큼의 range
  if df.iloc[row]["patient_id"] in d: # row행,"patient_id"열 : patient_id 가 d 안에 있으면,
    d[df.iloc[row]["patient_id"]].append(df.iloc[row]["image_id"]) # ????
  else:
    d[df.iloc[row]["patient_id"]]=[df.iloc[row]["image_id"]]  # d안에 없으면, 

  d1[df.iloc[row]["patient_id"]]=[df.iloc[row]["finding"]]

# %%
#images and findings associated with the first patient
print(d["CXR3676_IM-1829-0001"])
print(d1["CXR3676_IM-1829-0001"])
# Out:
# ['NLMCXR_png/CXR3676_IM-1829-0001-0001.png', 'NLMCXR_png/CXR3676_IM-1829-0001-0002.png']
# ["The cardiomediastinal silhouette appears irregular secondary to the diffuse bilateral pulmonary interstitial disease. The thoracic aorta is tortuous. Calcified lymph XXXX are demonstrated in the left hilum. No focal pulmonary consolidation. Diffuse increased bilateral pulmonary interstitial markings, consistent with the patient's history of known pulmonary fibrosis, with relative sparing of the bilateral lung apices. No pneumothorax or pleural effusion demonstrated. The thoracic spine appears intact."]

# %%
image1=[]
image2=[]
report=[]
patient_id=[]
for patient in d.keys():

  #if there is only one image for a person
  if len(d[patient])==1:   #만약 patient행의 len 이 1이면 >> ""['NLMCXR_png/CXR3676_IM-1829-0001-0001.png']""
    img1=d[patient][0]     #img1 = patient행의 0번째 있는 image
    img2=d[patient][0]     #img2 = patient행의 0번째 있는 image (복사)

  #if there are two images for a person
  elif len(d[patient])==2:   #만약 patient행의 len 이 2이면 >> ""['NLMCXR_png/CXR3676_IM-1829-0001-0001.png','두번쨰 이미지 filename']""
    img1=d[patient][0]       #img1 = patient행의 0번째 있는 image
    img2=d[patient][1]       #img2 = patient행의 1번째 있는 image
  
  #if there are three images for a person
  elif len(d[patient])==3:          #만약 len==3
    a=np.random.choice([0,1,2],2)   #a=임의표본 추출 -> 0,1,2 중에서 2개
    img1=d[patient][a[0]]           #img1 = a list에서 랜덤으로 뽑힌 0번째 image
    img2=d[patient][a[1]].          #img2 = a list에서 랜덤으로 뽑힌 1번째 image

  #if there are four images for a person
  elif len(d[patient])==4:
    a=np.random.choice([0,1,2,3],2)
    img1=d[patient][a[0]]
    img2=d[patient][a[1]]
    
  image1.append(img1)           #빈 리스트 image1에 img1 append
  image2.append(img2)
  report.append(d1[patient][0]) #빈 리스트 report에 d1에서 patient의 0번째 열들 append
  patient_id.append(patient)    #patient_id에 patient 이름 다 넣어주기

# %%
df_dash=pd.DataFrame()    #dataframe 만들어서
df_dash["patient_id"]=patient_id   #각 열에 넣어주기
df_dash["image1"]=image1
df_dash["image2"]=image2
df_dash["report"]=report
df_dash
# Out:
#                 patient_id  ...                                             report
# 0          CXR3696_IM-1846  ...  Heart size is normal and lungs are clear. Stab...
# 1     CXR3681_IM-1833-0001  ...  There are lower lung volumes. There is central...
# 2     CXR3676_IM-1829-0001  ...  The cardiomediastinal silhouette appears irreg...
# 3          CXR3671_IM-1827  ...  Stable cardiomediastinal silhouette. Mild patc...
# 4          CXR3677_IM-1830  ...  Heart size is within normal limits. Aorta is t...
# ...                    ...  ...                                                ...
# 3815       CXR1844_IM-0547  ...  Normal cardiomediastinal contours. Hyperexpans...
# 3816       CXR1871_IM-0564  ...  The cardiomediastinal contours are within norm...
# 3817       CXR1851_IM-0553  ...  Heart size is normal. No focal airspace consol...
# 3818       CXR1877_IM-0568  ...  Heart size normal. Lungs are clear. XXXX are n...
# ...

# %% [markdown]
# #Preprocessing the text data

# %%
# some sample report
print(df_dash["report"].values[:10])  #df['col_name'].values[]는 Pandas 데이터 프레임의 셀에서 값을 가져온다
# Out:
# ['Heart size is normal and lungs are clear. Stable 5 mm right midlung perform granuloma'
#  'There are lower lung volumes. There is central bronchovascular crowding. Volume loss in the medial right upper lobe seen on XXXX is not as well-demonstrated on radiography. No lobar consolidation. No pleural effusion or pneumothorax.'
#  "The cardiomediastinal silhouette appears irregular secondary to the diffuse bilateral pulmonary interstitial disease. The thoracic aorta is tortuous. Calcified lymph XXXX are demonstrated in the left hilum. No focal pulmonary consolidation. Diffuse increased bilateral pulmonary interstitial markings, consistent with the patient's history of known pulmonary fibrosis, with relative sparing of the bilateral lung apices. No pneumothorax or pleural effusion demonstrated. The thoracic spine appears intact."
# ...

# %%
#convert into lowercase
finding=df_dash["report"].values   #모든 value를 finding에 저장
for idx in tqdm(range(len(finding))):  #tqdm 진행사항표시바
    
    lower=finding[idx].lower()      #finding에서 index(숫자)를 가지고 와서 lower() 해주고 lower에 저장
    finding[idx]=lower              #finding에서 하나씩 불러온 것이 lower
  
df_dash["report"]=finding           #report를 lower 한 것으로 대체
# Out:
# 100%|██████████| 3820/3820 [00:00<00:00, 536470.95it/s]

# %%
#Now we need to expand the contractions like won't, can't, don't etc.
#https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = { 
"ain't": "am not / are not / is not / has not / have not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is / how does",
"i'd": "i had / i would",
"i'd've": "i would have",
"i'll": "i shall / I will",
"i'll've": "i shall have / i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have"
}



finding=df_dash["report"].values        #finding에 report열의 values를 list로 저장
for idx in tqdm(range(len(finding))):   #finding의 길이만큼 꺼내기
  list_of_words=finding[idx].split(" ") #finding에서 하나씩 꺼내서 띄어쓰기 단위로 list_of_word에 저장
  
  sentence=""                    # 비어있는 sentece 변수
  for i in list_of_words:        # list_of_words에서 word 단위로 하나씩 꺼내기
    
    if len(i)>2:          #만약 i 의 길이가 2 이상이고,
      
      if i in list(contractions.keys()):    #만약 i 가 contractions의 keys가 저장되어있는 list에 있으면 
        wrd=contractions[i]                   #wrd에 contraction[i]에 해당하는 value를 저장한다. ex)we're >> we are
      else:                                 #만약에 없으면
        wrd=i                                 #wrd= 그냥 i >> 그대로 가져온다는 말..
      
      sentence+=wrd+" "        # wrd에 띄어쓰기를 붙여가면서 sentence에 저장한다.
    else:                 #만약 i의 길이가 2 미만..?이면 
      continue            #계속한다.
  finding[idx]=sentence  #finding[idx]는 sentence로 바뀐다.
# Out:
# 100%|██████████| 3820/3820 [00:00<00:00, 9583.34it/s]

# %% [markdown]
# re.sub（정규 표현식, 뭘로 바꿀지 , 바꾸고 싶은 문자）

# %%
'''Now we remove all the special characters, and digits from the report. also remove the extra spaces in the sentence. Also there
are some words like xxx. These words are not giving any additional meaning to the report. So we remove those words
'''

for idx in tqdm(range(len(finding))):  #진행 상태바
    
  report=re.sub("[^a-z.]"," ",finding[idx])   #re.sub : re.sub（정규 표현식, 뭘로 바꿀지 , 바꾸고 싶은 문자）
  report=re.sub("xx+","",report)             
  report=re.sub(r'\b\w{1,2}\b',"",report) #some unwanted words came up which are having lenbth<2. They are also removed
  report=re.sub("\s\s+"," ",report)
  finding[idx]=report 
print("\n")
# Out:
# 100%|██████████| 3820/3820 [00:00<00:00, 42838.96it/s]

# %%
for i in finding[:10]:
  print(i)
# Out:
# heart size normal and lungs are clear. stable right midlung perform granuloma
# there are lower lung volumes. there central bronchovascular crowding. volume loss the medial right upper lobe seen not well demonstrated radiography. lobar consolidation. pleural effusion pneumothorax.
# the cardiomediastinal silhouette appears irregular secondary the diffuse bilateral pulmonary interstitial disease. the thoracic aorta tortuous. calcified lymph are demonstrated the left hilum. focal pulmonary consolidation. diffuse increased bilateral pulmonary interstitial markings consistent with the patient history known pulmonary fibrosis with relative sparing the bilateral lung apices. pneumothorax pleural effusion demonstrated. the thoracic spine appears intact.
# stable cardiomediastinal silhouette. mild patchy right upper lobe opacities similar slightly improved from . left lung clear. pleural effusion pneumothorax.
# ...

# %%
df_dash["report"]=finding
df_dash.to_csv("data.csv")
